# %% [markdown]
# <a href="https://colab.research.google.com/github/hmyrcmn/FaceMaskDetectionYolo/blob/main/handTrainTest_1/07kas%C4%B1m.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Nov  7 12:26:23 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8               9W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.28 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.7/112.6 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## unzip

# %%
import zipfile

# Zip dosyasının yolu
zip_dosyasi = "/content/drive/MyDrive/HıjyenDatayolo/nailData07YOLO.zip"
# Çıkarılacak klasörün yolu
hedef_klasor = "/content/Hand-2"

# Zip dosyasını aç ve içindekileri çıkar
with zipfile.ZipFile(zip_dosyasi, 'r') as zip_ref:
    zip_ref.extractall(hedef_klasor)

print(f"{zip_dosyasi} dosyası {hedef_klasor} klasörüne başarıyla çıkarıldı.")
# Out:
# /content/drive/MyDrive/HıjyenDatayolo/nailData07YOLO.zip dosyası /content/Hand-2 klasörüne başarıyla çıkarıldı.

# %%
# /content/data
import os
if os.path.isfile("/content/drive/MyDrive/HıjyenDatayolo/Result/resultHand07"):
    print("Dosya mevcut! (There is folder!)")
else:
    os.mkdir("/content/drive/MyDrive/HıjyenDatayolo/Result/resultHand07")

# %cd /content/drive/MyDrive/HıjyenDatayolo/Result/resultHand07
# Out:
# /content/drive/MyDrive/HıjyenDatayolo/Result/resultHand07

# %%
# /content/data
import os
if os.path.isfile("/content/drive/MyDrive/HıjyenData/YOLODataset-1/Result/"):
    print("Dosya mevcut! (There is folder!)")
else:
    os.mkdir("/content/drive/MyDrive/HıjyenData/YOLODataset-1/Result/")

# %cd /content/drive/MyDrive/HıjyenData/YOLODataset-1/Result/
# Out:
# /content/drive/MyDrive/HıjyenData/YOLODataset-1/Result

# %%
# %cd /content/drive/MyDrive/HıjyenData/YOLODataset-1/Result
# Out:
# /content/drive/MyDrive/HıjyenData/YOLODataset-1/Result

# %%
from ultralytics import YOLO
# !yolo task=detect mode=train  model=yolov8n.pt data= /content/Hand/yolodataHand/data.yaml epochs=10 imgsz=640
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 106MB/s]
# Ultralytics 8.3.24 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
# !yolo task=detect mode=train  model=yolov8n.pt data= /content/Hand/yolodataHand/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.24 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
# !yolo task=detect mode=train  model=/content/Result2/yolo11n.pt data= /content/Hand/yolodataHand/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.24 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
# !yolo task=detect mode=train  model=/content/Result2/yolo11n.pt data= /content/Hand/yolodataHand/data.yaml epochs=200 imgsz=640 batch=32 lr0=0.001
# Out:
# Ultralytics 8.3.24 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # new set deneme

# %%
from ultralytics import YOLO
# !yolo task=detect mode=train  model=/content/Result2/yolo11n.pt data=/content/Hand-2/yolodataHand/data.yaml epochs=200 imgsz=640 batch=32 lr0=0.001
# Out:
# Ultralytics 8.3.24 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
# !yolo task=detect mode=train  model=/content/Result2/yolo11n.pt data=/content/Hand-2/yolodataHand/data.yaml epochs=200 imgsz=640 batch=128 lr0=0.001
# Out:
# Ultralytics 8.3.24 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !cp -r /content/Result2/runs/detect/train7 /content/drive/MyDrive/HıjyenDatayolo/Result/

# %% [markdown]
# # 07 kasım hand data train

# %%
from ultralytics import YOLO
# !yolo task=detect mode=train  model=yolo11n.pt data=/content/Hand-2/nailData07YOLO/dataset.yaml epochs=200 imgsz=640 batch=32 lr0=0.001
# Out:
# ...
# 100% 5.35M/5.35M [00:00<00:00, 96.1MB/s]
# Ultralytics 8.3.28 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # 07 kasım result file

# %%
/content/drive/MyDrive/HıjyenDatayolo/Result/resultHand07

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs/detect/train

# %%
from ultralytics import YOLO
# !yolo train model=/content/Result2/yolo11n.pt data= /content/drive/MyDrive/HıjyenData/YOLODataset-1/dataset.yaml epochs=10 imgsz=640
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 107MB/s]
# Ultralytics 8.3.22 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd /content/Result2
# Out:
# /content/Result2

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="sxNxKxQ0qmOPRhofPflr")
project = rf.workspace("bfr-kfvcj").project("mask-and-hairnet-detection")
version = project.version(4)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to mask-and-hairnet-detection-4 in yolov11:: 100%|██████████| 530/530 [00:00<00:00, 6825.85it/s]

# %%
dataset.location
# Out:
# '/content/Result2/mask-and-hairnet-detection-4'

# %%
# !yolo task=detect mode=train  data=/content/Result2/mask-and-hairnet-detection-4/data.yaml model=yolo11n.pt epochs=10 imgsz=640
# Out:
# Ultralytics 8.3.22 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
