# %% [markdown]
# <a href="https://colab.research.google.com/github/hmyrcmn/FaceMaskDetectionYolo/blob/main/maksTrainH%C4%B1jyen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.24 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.3/112.6 GB disk)

# %%
import zipfile

# Zip dosyasının yolu
zip_dosyasi = "/content/drive/MyDrive/hıjyenDATA/MaskBoneYoloData.zip"
# Çıkarılacak klasörün yolu
hedef_klasor = "/content/drive/MyDrive/hıjyenDATA/"

# Zip dosyasını aç ve içindekileri çıkar
with zipfile.ZipFile(zip_dosyasi, 'r') as zip_ref:
    zip_ref.extractall(hedef_klasor)

print(f"{zip_dosyasi} dosyası {hedef_klasor} klasörüne başarıyla çıkarıldı.")
# Out:
# /content/drive/MyDrive/hıjyenDATA/MaskBoneYoloData.zip dosyası /content/drive/MyDrive/hıjyenDATA/ klasörüne başarıyla çıkarıldı.

# %%
# /content/data
import os
if os.path.isfile("/content/drive/MyDrive/hıjyenDATA/Result/"):
    print("Dosya mevcut! (There is folder!)")
else:
    os.mkdir("/content/drive/MyDrive/hıjyenDATA/Result/")

# %cd /content/drive/MyDrive/hıjyenDATA/Result/
# Out:
# /content/drive/MyDrive/hıjyenDATA/Result

# %%
# !pip install tensorboard

# %load_ext tensorboard
# %tensorboard --logdir runs/detect/train

# %%
from ultralytics import YOLO
# !yolo task=detect mode=train  model=yolov8n.pt data= /content/drive/MyDrive/hıjyenDATA/MaskBoneYoloData/data.yaml epochs=100 imgsz=640
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 102MB/s]
# Ultralytics 8.3.24 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
# !yolo task=detect mode=train  model=yolov8n.pt data= /content/drive/MyDrive/hıjyenDATA/MaskBoneYoloData/data.yaml epochs=10 imgsz=640 batch=64 l40=0.01
