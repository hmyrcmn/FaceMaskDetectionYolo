# %% [markdown]
# <a href="https://colab.research.google.com/github/hmyrcmn/FaceMaskDetectionYolo/blob/main/modelOptimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from zipfile import ZipFile

def unzip(zip_path, extract_path):
    with ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

# Kullanım örneği
# Lütfen aşağıdaki dosya yollarını kendi projenize uygun şekilde güncelleyin.
zip_file_path = '/content/drive/MyDrive/kısa/DATA9/koridorInput.zip'
extracted_path = '/content/data/images'

unzip(zip_file_path, extracted_path)

# %%
import os
import shutil

def move_images_with_labels(label_folder, image_folder, destination_folder):
    moved_files = []  # Taşınan dosyaların listesi

    # Label klasöründeki .txt dosyalarını listele
    txt_files = [file for file in os.listdir(label_folder) if file.endswith('.txt')]

    # Her .txt dosyası için işlem yap
    for txt_file in txt_files:
        # .txt dosyanın adı (uzantısız)
        base_name = os.path.splitext(txt_file)[0]

        # .png dosyasının adı
        png_file = f"{base_name}.png"

        # .png dosyasının tam yolu
        source_png = os.path.join(image_folder, png_file)

        # Eğer .png dosyası varsa taşı
        if os.path.exists(source_png):
            # .png dosyasını yeni klasöre taşı
            destination_png = os.path.join(destination_folder, png_file)
            shutil.move(source_png, destination_png)

            # Taşınan dosyaların adını listeye ekle
            moved_files.append(png_file)

    return moved_files

# Kaynak ve hedef klasörlerini belirt
label_folder = '/content/data/labels'  # Etiket dosyalarının bulunduğu klasör
image_folder = '/content/data/images/koridorInput'  # Resim dosyalarının bulunduğu klasör
destination_folder = '/content/t'  # Resim dosyalarının taşınacağı klasör

# Dosyaları taşı ve taşınan dosyaları yazdır
moved_files = move_images_with_labels(label_folder, image_folder, destination_folder)
print("Taşınan dosyalar:")
for moved_file in moved_files:
    print(moved_file)
# Out:
# Taşınan dosyalar:
# 01461.png
# 00890.png
# 01145.png
# 01369.png
# 01197.png
# 00651.png
# 00922.png
# 00841.png
# 00933.png
# 01092.png
# 01493.png
# 00916.png
# 00810.png
# 00975.png
# 00508.png
# 01494.png
# 01427.png
# 00986.png
# 01223.png
# 01137.png
# 00961.png
# 00631.png
# 00588.png
# 00561.png
# 00001.png
# 00003.png
# 01117.png
# 00914.png
# 00231.png
# 01182.png
# 00613.png
# 01419.png
# 00735.png
# 00929.png
# 01394.png
# 00699.png
# 00900.png
# 00004.png
# 00108.png
# 01342.png
# 01065.png
# 01338.png
# 01333.png
# 00686.png
# 00956.png
# 01160.png
# 00736.png
# 01045.png
# 00893.png
# 01373.png
# 01353.png
# 00577.png
# 00817.png
# 01230.png
# 01084.png
# 00329.png
# 01207.png
# 01031.png
# 01433.png
# 00414.png
# 01009.png

# %%
import os
from zipfile import ZipFile

def zip_files(folder_path, zip_name):
    with ZipFile(zip_name, 'w') as zipf:
        for root, _, files in os.walk(folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                zipf.write(file_path, os.path.relpath(file_path, folder_path))

# Örnek kullanım
zip_files('/content/a/l', '/content/a/l.zip')

# %%
# !pip install ultralytics
# !nvidia-smi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.9/645.9 kB 10.8 MB/s eta 0:00:00
# ...
# Tue Nov 28 06:33:22 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# ...

# %%
from ultralytics import YOLO

# !yolo train model=yolov8n.pt data=/content/data.yaml epochs=10 imgsz=640
# Out:
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
from ultralytics import YOLO

# !yolo train model=yolov8n.pt data=/content/data.yaml epochs=20 imgsz=640
# Out:
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

# !yolo train model=yolov8n.pt data=/content/data.yaml epochs=30 imgsz=640
# Out:
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

# !yolo train model=yolov8n.pt data=/content/data.yaml epochs=40 imgsz=640
# Out:
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

# !yolo train model=yolov8n.pt data=/content/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

# !yolo train model=yolov8n.pt data=/content/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import cv2

video_path = '/content/drive/MyDrive/kısa/TurnikeKısa.mp4'
cap = cv2.VideoCapture(video_path)


# !yolo predict model=/content/runs/detect/train7/weights/best.pt source='/content/drive/MyDrive/kısa/TurnikeKısa.mp4'
# Out:
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006818 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (1/1614) /content/drive/MyDrive/kısa/TurnikeKısa.mp4: 384x640 1 boneli, 1 bonesiz, 1 onluklu, 90.6ms
# video 1/1 (2/1614) /content/drive/MyDrive/kısa/TurnikeKısa.mp4: 384x640 1 boneli, 1 bonesiz, 1 onluklu, 6.3ms
# video 1/1 (3/1614) /content/drive/MyDrive/kısa/TurnikeKısa.mp4: 384x640 1 boneli, 1 bonesiz, 1 onluklu, 6.8ms
# video 1/1 (4/1614) /content/drive/MyDrive/kısa/TurnikeKısa.mp4: 384x640 1 bonesiz, 1 onluklu, 6.8ms
# video 1/1 (5/1614) /content/drive/MyDrive/kısa/TurnikeKısa.mp4: 384x640 1 bonesiz, 1 onluklu, 6.9ms
# video 1/1 (6/1614) /content/drive/MyDrive/kısa/TurnikeKısa.mp4: 384x640 1 bonesiz, 1 onluklu, 6.3ms
# video 1/1 (7/1614) /content/drive/MyDrive/kısa/TurnikeKısa.mp4: 384x640 1 bonesiz, 1 onluklu, 6.2ms
# ...

# %%
# Gerekli kütüphaneyi yükleyin
# !apt-get install ffmpeg

# AVI dosyasını MP4 formatına dönüştürün
# !ffmpeg -i /content/runs/detect/predict5/TurnikeKısa.avi /content/drive/MyDrive/kısa/DATA11/yerelkaynakTURNIKEV3.mp4
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 10 not upgraded.
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# !yolo train model=/content/best.pt data=/content/data.yaml epochs=10 imgsz=640 batch=16
# Out:
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo train model=/content/runs/detect/train3/weights/best.pt data=/content/data.yaml epochs=10 imgsz=640 batch=16
# Out:
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo train model=/content/runs/detect/train4/weights/best.pt data=/content/data.yaml epochs=10 imgsz=640 batch=16
# Out:
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo train model=/content/runs/detect/train5/weights/best.pt data=/content/data.yaml epochs=100 imgsz=640 lr=0.001
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 387, in entrypoint
#     check_dict_alignment(full_args_dict, overrides)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 205, in check_dict_alignment
#     raise SyntaxError(string + CLI_HELP_MSG) from e
# SyntaxError: 'lr' is not a valid YOLO argument. Similar arguments are i.e. ['lrf=0.01', 'lr0=0.01'].
#
#     Arguments received: ['yolo', 'train', 'model=/content/runs/detect/train5/weights/best.pt', 'data=/content/data.yaml', 'epochs=100', 'imgsz=640', 'lr=0.001']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ('detect', 'segment', 'classify', 'pose')
#                 MODE (required) is one of ('train', 'val', 'predict', 'export', 'track', 'benchmark')
# ...

# %%
# !yolo train model=/content/runs/detect/train5/weights/best.pt data=/content/data.yaml epochs=100 imgsz=640 lr=0.001
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 387, in entrypoint
#     check_dict_alignment(full_args_dict, overrides)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 205, in check_dict_alignment
#     raise SyntaxError(string + CLI_HELP_MSG) from e
# SyntaxError: 'lr' is not a valid YOLO argument. Similar arguments are i.e. ['lrf=0.01', 'lr0=0.01'].
#
#     Arguments received: ['yolo', 'train', 'model=/content/runs/detect/train5/weights/best.pt', 'data=/content/data.yaml', 'epochs=100', 'imgsz=640', 'lr=0.001']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ('detect', 'segment', 'classify', 'pose')
#                 MODE (required) is one of ('train', 'val', 'predict', 'export', 'track', 'benchmark')
# ...

# %%
# !yolo train  model=/content/runs/detect/train5/weights/best.pt  data=/content/data.yaml epochs=200 imgsz=640 lr=0.001
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 387, in entrypoint
#     check_dict_alignment(full_args_dict, overrides)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 205, in check_dict_alignment
#     raise SyntaxError(string + CLI_HELP_MSG) from e
# SyntaxError: 'lr' is not a valid YOLO argument. Similar arguments are i.e. ['lrf=0.01', 'lr0=0.01'].
#
#     Arguments received: ['yolo', 'train', 'model=/content/runs/detect/train5/weights/best.pt', 'data=/content/data.yaml', 'epochs=200', 'imgsz=640', 'lr=0.001']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ('detect', 'segment', 'classify', 'pose')
#                 MODE (required) is one of ('train', 'val', 'predict', 'export', 'track', 'benchmark')
# ...

# %%
# !yolo train model=yolov8n.pt data=/content/data.yaml epochs=100 imgsz=640 lr=0.001 batch=32

# %%
import os
from PIL import Image

def resize_png(input_path, output_path, width, height):
    # PNG dosyasını aç
    with Image.open(input_path) as img:
        # Belirtilen boyuta dönüştür
        resized_img = img.resize((width, height))
        # Dönüştürülmüş resmi kaydet
        resized_img.save(output_path)

def resize_all_pngs(input_folder, output_folder, width, height):
    # Çıkış klasörü yoksa oluştur
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Giriş klasöründeki tüm PNG dosyalarını listele
    input_files = [f for f in os.listdir(input_folder) if f.endswith('.png')]

    for input_file in input_files:
        # Giriş ve çıkış dosya yollarını oluştur
        input_path = os.path.join(input_folder, input_file)
        output_path = os.path.join(output_folder, input_file)

        # PNG dosyasını belirtilen boyuta dönüştür
        resize_png(input_path, output_path, width, height)

# Kullanım örneği
input_folder_path = '/content/a/i'
output_folder_path = '/content/a/l'
new_width = 640
new_height = 540
resize_all_pngs(input_folder_path, output_folder_path, new_width, new_height)
